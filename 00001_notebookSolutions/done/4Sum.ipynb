# %%
from typing import List

class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        d = {}
        for i in range(len(nums)):
            for j in range(i+1, len(nums)):
                sum2 = nums[i] + nums[j]
                if sum2 in d:
                    d[sum2].append((i, j))
                else:
                    d[sum2] = [(i, j)]
        
        print (d)
        
        result = set()
        for key in d:
            value = target - key
            # print (key, value)
            if value in d:
                list1 = d[key]
                list2 = d[value]
                for (i,j) in list1:
                    for (k,l) in list2:
                        if i != k and i != l and j != k and j != l:
                            flist = [nums[i], nums[j], nums[k], nums[l]]
                            flist.sort()
                            result.add(tuple(flist))
        
        
        return list(result)

class Solution2:
    def fourSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[List[int]]
        """
        d = dict()
        for i in range(len(nums)):
            for j in range(i+1,len(nums)):
                sum2 = nums[i]+nums[j]
                if sum2 in d:
                    d[sum2].append((i,j))
                else:
                    d[sum2] = [(i,j)]
        
        print (d)
        result = set()
        for key in d:
            value = target - key
            if value in d:
                list1 = d[key]
                list2 = d[value]
                for (i,j) in list1:
                    for (k,l) in list2:
                        if i!=k and i!=l and j!=k and j!=l:
                            flist = [nums[i],nums[j],nums[k],nums[l]]
                            flist.sort()
                            result.add(tuple(flist))
        return list(result)
    
class Solution3:
    def fourSum(self, nums, target, N, result, results):
        if len(nums) < N or N < 2 or target < nums[0]*N or target > nums[-1]*N:
            return
        
        if N == 2:
            l,r = 0,len(nums)-1
            while l < r:
                s = nums[l] + nums[r]
                if s == target:
                    results.append(result + [nums[l], nums[r]])
                    l += 1
                    while l < r and nums[l] == nums[l-1]:
                        l += 1
                elif s < target:
                    l += 1
                else:
                    r -= 1
        else:
            for i in range(len(nums)-N+1):
                if i == 0 or ( i > 0 and nums[i] != nums[i-1]):
                    self.fourSum(nums, target-nums[i], N-1, result+[nums[i]], results)

# %%
nums = [1,0,-1,0,-2,2]
target = 0

a = Solution()
print (a.fourSum(nums, target))

b = Solution2()
print (b.fourSum(nums, target))

c = Solution3()
results = []
c.fourSum(sorted(nums), target, 4, [], results)
print (results)
# Out:
# {1: [(0, 1), (0, 3), (2, 5)], 0: [(0, 2), (1, 3), (4, 5)], -1: [(0, 4), (1, 2), (2, 3)], 3: [(0, 5)], -2: [(1, 4), (3, 4)], 2: [(1, 5), (3, 5)], -3: [(2, 4)]}
# [(-2, -1, 1, 2), (-1, 0, 0, 1), (-2, 0, 0, 2)]
# {1: [(0, 1), (0, 3), (2, 5)], 0: [(0, 2), (1, 3), (4, 5)], -1: [(0, 4), (1, 2), (2, 3)], 3: [(0, 5)], -2: [(1, 4), (3, 4)], 2: [(1, 5), (3, 5)], -3: [(2, 4)]}
# [(-2, -1, 1, 2), (-1, 0, 0, 1), (-2, 0, 0, 2)]
# [[-2, -1, 1, 2], [-2, 0, 0, 2], [-1, -2, 1, 2], [-1, -1, 0, 2], [-1, 0, -1, 2], [-1, 0, 0, 1], [0, -2, 0, 2], [0, -1, -1, 2], [0, -1, 0, 1], [0, 0, -2, 2], [0, 0, -1, 1], [0, 0, 0, 0]]
